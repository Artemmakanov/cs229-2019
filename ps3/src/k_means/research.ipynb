# %%
from matplotlib.image import imread; import matplotlib.pyplot as plt;

# %%
A = imread('peppers-small.tiff')

# %%
A[:, :, 0]
# Out:
# array([[168, 177, 179, ..., 169, 166, 149],
#        [175, 187, 184, ..., 162, 161, 147],
#        [168, 186, 183, ..., 159, 155, 146],
#        ...,
#        [138, 150, 164, ..., 164, 177, 184],
#        [126, 137, 170, ..., 182, 178, 184],
#        [122, 127, 169, ..., 183, 182, 180]], dtype=uint8)

# %%
A[:, :, 1]
# Out:
# array([[ 60,  70,  68, ..., 165, 164, 160],
#        [ 71,  85,  83, ..., 207, 204, 200],
#        [ 67,  83,  81, ..., 202, 199, 198],
#        ...,
#        [102, 160, 159, ..., 172, 199, 206],
#        [112, 140, 166, ..., 207, 205, 210],
#        [104, 124, 168, ..., 212, 213, 206]], dtype=uint8)

# %%
A[:, :, 2]
# Out:
# array([[ 54,  66,  68, ..., 106, 104, 100],
#        [ 38,  46,  45, ...,  88,  88,  85],
#        [ 35,  43,  41, ...,  89,  87,  84],
#        ...,
#        [ 39,  63,  66, ..., 132, 146, 157],
#        [ 42,  54,  73, ..., 173, 165, 168],
#        [ 41,  49,  74, ..., 178, 175, 164]], dtype=uint8)

# %%
plt.imshow(A); plt.show();

# %%
sorted([1, 2,4, 5])
# Out:
# [1, 2, 4, 5]
